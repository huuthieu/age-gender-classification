# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !pip install mxnet-cu110
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 327.3 MB 6.2 kB/s
# ...
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ...

# %%
import mxnet as mx
a = mx.nd.ones((2, 3), mx.gpu())
b = a * 2 + 1
b.asnumpy()
# Out:
# array([[3., 3., 3.],
#        [3., 3., 3.]], dtype=float32)

# %%
# !git clone https://github.com/huuthieu/age-gender-classification.git
# Out:
# fatal: destination path 'age-gender-classification' already exists and is not an empty directory.

# %%
ROOT = '/content/age-gender-classification'
DATA_PATH = '/content/age-gender-classification/adience'

# %%
# !mkdir age-gender-classification/adience
# !mkdir age-gender-classification/adience/lists
# !mkdir age-gender-classification/adience/rec
# Out:
# mkdir: cannot create directory ‘age-gender-classification/adience’: File exists

# %%
# !cp -r '/content/drive/MyDrive/Colab Notebooks/aligned.tar.gz' '/content/age-gender-classification/adience/'

# %%
# !cp -r '/content/drive/MyDrive/Colab Notebooks/folds' '/content/age-gender-classification/adience'

# %%
# !tar -xvf '/content/age-gender-classification/adience/aligned.tar.gz'
# Out:
# Streaming output truncated to the last 5000 lines.
# aligned/29671106@N00/landmark_aligned_face.187.11506288685_2e47242bdc_o.jpg
# aligned/68825596@N05/landmark_aligned_face.300.11593439365_73c9003774_o.jpg
# aligned/115321157@N03/landmark_aligned_face.1744.12113482854_a8a16849a0_o.jpg
# aligned/28754132@N06/landmark_aligned_face.613.9691322182_172a307a44_o.jpg
# aligned/62282816@N03/landmark_aligned_face.1470.11768418795_7789dc0293_o.jpg
# aligned/110095806@N05/landmark_aligned_face.1532.11853219594_094f4b23ac_o.jpg
# aligned/10148140@N07/landmark_aligned_face.1956.10318835885_5fdc0b99a2_o.jpg
# aligned/115321157@N03/landmark_aligned_face.1745.12113084426_0438f67c9a_o.jpg
# aligned/111700049@N08/landmark_aligned_face.1546.11833084074_de1283dbd8_o.jpg
# aligned/66870968@N06/landmark_aligned_face.1226.11326321063_a740aafebb_o.jpg
# aligned/34158582@N02/landmark_aligned_face.401.9619512978_dd982e9d05_o.jpg
# aligned/7636528@N03/landmark_aligned_face.1052.11486778763_4a73c8f860_o.jpg
# ...

# %%
# !mv '/content/aligned' '/content/age-gender-classification/adience'

# %%
# !mkdir output

# %%
# !python /content/age-gender-classification/build_dataset.py
# Out:
# [INFO] building paths and labels...
# [INFO] encoding labels...
# [INFO] constructing validation data...
# [INFO] constructing testing data...
# [INFO] building /content/age-gender-classification/adience/lists/age_train.lst...
# Building List: 100% |###########################################| Time:  0:01:20
# [INFO] building /content/age-gender-classification/adience/lists/age_val.lst...
# Building List: 100% |###########################################| Time:  0:00:00
# [INFO] building /content/age-gender-classification/adience/lists/age_test.lst...
# Building List: 100% |###########################################| Time:  0:00:00
# [INFO] serializing means...
# [INFO] serializing label encoder...

# %%
# !/usr/local/lib/python3.7/dist-packages/mxnet/tools/im2rec.py /content/age-gender-classification/adience/lists/gender_train.lst /content/age-gender-classification/adience/rec/gender_train.rec --resize=256 --encoding='.jpg' --quality=100
# !/usr/local/lib/python3.7/dist-packages/mxnet/tools/im2rec.py /content/age-gender-classification/adience/lists/gender_val.lst /content/age-gender-classification/adience/rec/gender_val.rec --resize=256 --encoding='.jpg' --quality=100
# !/usr/local/lib/python3.7/dist-packages/mxnet/tools/im2rec.py /content/age-gender-classification/adience/lists/gender_test.lst /content/age-gender-classification/adience/rec/gender_test.rec --resize=256 --encoding='.jpg' --quality=100
# Out:
# Creating .rec file from /content/age-gender-classification/adience/lists/gender_val.lst in /content/age-gender-classification/adience/lists
# multiprocessing not available, fall back to single threaded encoding
# time: 0.013108015060424805  count: 0
# time: 10.791592121124268  count: 1000
# Creating .rec file from /content/age-gender-classification/adience/lists/gender_test.lst in /content/age-gender-classification/adience/lists
# multiprocessing not available, fall back to single threaded encoding
# time: 0.01242828369140625  count: 0
# time: 10.674453258514404  count: 1000

# %%
# !/usr/local/lib/python3.7/dist-packages/mxnet/tools/im2rec.py /content/age-gender-classification/adience/lists/age_train.lst /content/age-gender-classification/adience/rec/age_train.rec --resize=256 --encoding='.jpg' --quality=100
# !/usr/local/lib/python3.7/dist-packages/mxnet/tools/im2rec.py /content/age-gender-classification/adience/lists/age_val.lst /content/age-gender-classification/adience/rec/age_val.rec --resize=256 --encoding='.jpg' --quality=100
# !/usr/local/lib/python3.7/dist-packages/mxnet/tools/im2rec.py /content/age-gender-classification/adience/lists/age_test.lst /content/age-gender-classification/adience/rec/age_test.rec --resize=256 --encoding='.jpg' --quality=100
# Out:
# Creating .rec file from /content/age-gender-classification/adience/lists/age_train.lst in /content/age-gender-classification/adience/lists
# multiprocessing not available, fall back to single threaded encoding
# time: 0.021988391876220703  count: 0
# time: 10.710134983062744  count: 1000
# time: 11.017812252044678  count: 2000
# time: 10.624943494796753  count: 3000
# time: 10.95951247215271  count: 4000
# time: 11.077194929122925  count: 5000
# time: 11.227375984191895  count: 6000
# time: 10.859864950180054  count: 7000
# Creating .rec file from /content/age-gender-classification/adience/lists/age_val.lst in /content/age-gender-classification/adience/lists
# multiprocessing not available, fall back to single threaded encoding
# time: 0.01166844367980957  count: 0
# time: 10.810124397277832  count: 1000
# Creating .rec file from /content/age-gender-classification/adience/lists/age_test.lst in /content/age-gender-classification/adience/lists
# ...

# %%
# !mv /content/age-gender-classification/adience/lists/*.rec /content/age-gender-classification/adience/rec
# !mv /content/age-gender-classification/adience/lists/*.idx /content/age-gender-classification/adience/rec

# %%
# !mkdir /content/age-gender-classification/checkpoints
# !mkdir /content/age-gender-classification/checkpoints/age
# !mkdir /content/age-gender-classification/checkpoints/gender

# %%
# !python /content/age-gender-classification/train.py --checkpoints '/content/drive/MyDrive/Colab Notebooks/age_gender/age' --prefix agenet
# Out:
# [15:06:11] ../src/io/iter_image_recordio_2.cc:177: ImageRecordIOParser2: /content/age-gender-classification/adience/rec/age_train.rec, use 1 threads for decoding..
# [15:06:14] ../src/io/iter_image_recordio_2.cc:177: ImageRecordIOParser2: /content/age-gender-classification/adience/rec/age_val.rec, use 1 threads for decoding..
# [INFO] building network...
# /content/age-gender-classification/train.py:91: DeprecationWarning: mxnet.model.FeedForward has been deprecated. Please use mxnet.mod.Module instead.
#   begin_epoch=args["start_epoch"])
# [INFO] training network...
# [15:06:21] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:96: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
